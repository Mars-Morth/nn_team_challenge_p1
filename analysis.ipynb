# %%
import pandas as pd
import numpy as np
INPUT_CSV = "nimbus_orders_clean.csv"

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'customer_name', 'city', 'state',
#        'order_date', 'category', 'product', 'quantity', 'unit_price', 'total'],
#       dtype='str')

# %%
print(df["city"].unique())
df["city"] = df["city"].replace({"NEW YORK": "New York",  " New York": "New York"})
print(df["city"].unique())
print(len(df["city"] == "New York"))
# Out:
# <StringArray>
# [     'Denver',     'Seattle',     'Atlanta',     'Houston',       'Miami',
#       'Boston',     'Chicago',     'CHICAGO',      'Austin', 'Los Angeles',
#      'Phoenix',    'Portland',          'LA', 'los angeles',    'New York',
#      'PHOENIX',    'PORTLAND',      'AUSTIN',     'HOUSTON',     'ATLANTA']
# Length: 20, dtype: str
# <StringArray>
# [     'Denver',     'Seattle',     'Atlanta',     'Houston',       'Miami',
#       'Boston',     'Chicago',     'CHICAGO',      'Austin', 'Los Angeles',
#      'Phoenix',    'Portland',          'LA', 'los angeles',    'New York',
#      'PHOENIX',    'PORTLAND',      'AUSTIN',     'HOUSTON',     'ATLANTA']
# Length: 20, dtype: str
# 94
